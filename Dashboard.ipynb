# %%
# %run "Code.ipynb"
# Out:
# Enter your testing text: What is the sales of Prd1 in USA?
# Do you want this for all years and quarters (y/n): y
#    Country Quarter  Year Local Product   US$ MNF
# 0       US      Q1  2016         Prod1   8676876
# 3       US      Q1  2017         Prod1   1903166
# 6       US      Q1  2018         Prod1  16572052
# 9       US      Q2  2016         Prod1  11372824
# 12      US      Q2  2017         Prod1  16083151
# 15      US      Q2  2018         Prod1  15597513
# 18      US      Q3  2016         Prod1  23850295
# 21      US      Q3  2017         Prod1  16315687
# 24      US      Q3  2018         Prod1  18484428
# 27      US      Q4  2016         Prod1   5895294
# 30      US      Q4  2017         Prod1   5185555
# 33      US      Q4  2018         Prod1  18371149
# Total sales is 158307990 $
# Do you have any more questions(y/n): n
